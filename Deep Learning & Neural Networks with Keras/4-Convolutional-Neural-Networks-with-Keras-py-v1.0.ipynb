# %% [markdown]
# <div align="center">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/FinalModule_Coursera/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </div>
#
# <h1 align=center><font size = 5>Convolutional Neural Networks with Keras</font></h1>

# %% [markdown]
# In this lab, we will learn how to use the Keras library to build convolutional neural networks. We will also use the popular MNIST dataset and we will compare our results to using a conventional neural network.

# %% [markdown]
# <h2>Convolutional Neural Networks with Keras</h2>
#
# <h3>Objective for this Notebook<h3>
# <h5> 1. How to use the Keras library to build convolutional neural networks.</h5>
# <h5> 2. Convolutional Neural Network with One Convolutional and Pooling Layers.</h5>
# <h5> 3. Convolutional Neural Network with Two Convolutional and Pooling Layers.</h5>

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1.  <a href="https://#item41">Import Keras and Packages</a>
# 2.  <a href="https://#item42">Convolutional Neural Network with One Convolutional and Pooling Layers</a>
# 3.  <a href="https://#item43">Convolutional Neural Network with Two Convolutional and Pooling Layers</a>
#
# </font>
# </div>

# %% [markdown]
# <a id='item41'></a>

# %% [markdown]
# ## Import Keras and Packages

# %% [markdown]
# Let's start by importing the keras libraries and the packages that we would need to build a neural network.

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# When working with convolutional neural networks in particular, we will need additional packages.

# %%
from tensorflow.keras.layers import Conv2D # to add convolutional layers
from tensorflow.keras.layers import MaxPooling2D # to add pooling layers
from tensorflow.keras.layers import Flatten # to flatten data for fully connected layers

# %% [markdown]
# <a id='item42'></a>

# %% [markdown]
# ## Convolutional Layer with One set of convolutional and pooling layers

# %%
# import data
from tensorflow.keras.datasets import mnist

# load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# reshape to be [samples][pixels][width][height]
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32')

# %% [markdown]
# Let's normalize the pixel values to be between 0 and 1

# %%
X_train = X_train / 255 # normalize training data
X_test = X_test / 255 # normalize test data

# %% [markdown]
# Next, let's convert the target variable into binary categories

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

num_classes = y_test.shape[1] # number of categories

# %% [markdown]
# Next, let's define a function that creates our model. Let's start with one set of convolutional and pooling layers.

# %%
def convolutional_model():
    
    # create model
    model = Sequential()
    model.add(Conv2D(16, (5, 5), strides=(1, 1), activation='relu', input_shape=(28, 28, 1)))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    # compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])
    return model

# %% [markdown]
# Finally, let's call the function to create the model, and then let's train it and evaluate it.

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=1)
# Out:
# Epoch 1/10
# 300/300 [==============================] - 8s 26ms/step - loss: 0.2901 - accuracy: 0.9189 - val_loss: 0.1011 - val_accuracy: 0.9716
# Epoch 2/10
# 300/300 [==============================] - 8s 27ms/step - loss: 0.0838 - accuracy: 0.9759 - val_loss: 0.0596 - val_accuracy: 0.9803
# Epoch 3/10
# 300/300 [==============================] - 8s 27ms/step - loss: 0.0561 - accuracy: 0.9834 - val_loss: 0.0466 - val_accuracy: 0.9844
# Epoch 4/10
# 300/300 [==============================] - 8s 27ms/step - loss: 0.0442 - accuracy: 0.9870 - val_loss: 0.0424 - val_accuracy: 0.9869
# Epoch 5/10
# 300/300 [==============================] - 8s 27ms/step - loss: 0.0352 - accuracy: 0.9895 - val_loss: 0.0402 - val_accuracy: 0.9872
# Epoch 6/10
# 300/300 [==============================] - 9s 29ms/step - loss: 0.0307 - accuracy: 0.9903 - val_loss: 0.0368 - val_accuracy: 0.9866
# Epoch 7/10
# 300/300 [==============================] - 8s 28ms/step - loss: 0.0237 - accuracy: 0.9927 - val_loss: 0.0368 - val_accuracy: 0.9882
# Epoch 8/10
# 300/300 [==============================] - 9s 29ms/step - loss: 0.0215 - accuracy: 0.9937 - val_loss: 0.0402 - val_accuracy: 0.9861
# Epoch 9/10
# 300/300 [==============================] - 9s 29ms/step - loss: 0.0182 - accuracy: 0.9947 - val_loss: 0.0329 - val_accuracy: 0.9878
# Epoch 10/10
# 300/300 [==============================] - 9s 29ms/step - loss: 0.0147 - accuracy: 0.9957 - val_loss: 0.0363 - val_accuracy: 0.9884

# %%
# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Accuracy: 0.9883999824523926
#  Error: 1.1600017547607422

# %% [markdown]
# ***

# %% [markdown]
# <a id='item43'></a>

# %% [markdown]
# ## Convolutional Layer with two sets of convolutional and pooling layers

# %% [markdown]
# Let's redefine our convolutional model so that it has two convolutional and pooling layers instead of just one layer of each.

# %%
def convolutional_model2():
    
    # create model
    model = Sequential()
    model.add(Conv2D(16, (5, 5), activation='relu', input_shape=(28, 28, 1)))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Conv2D(8, (2, 2), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    # Compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])
    return model

# %% [markdown]
# Now, let's call the function to create our new convolutional neural network, and then let's train it and evaluate it.

# %%
# build the model
model = convolutional_model2()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=1)
# Out:
# Epoch 1/10
# 300/300 [==============================] - 11s 34ms/step - loss: 0.4897 - accuracy: 0.8592 - val_loss: 0.1440 - val_accuracy: 0.9581
# Epoch 2/10
# 300/300 [==============================] - 9s 31ms/step - loss: 0.1233 - accuracy: 0.9638 - val_loss: 0.0910 - val_accuracy: 0.9715
# Epoch 3/10
# 300/300 [==============================] - 10s 32ms/step - loss: 0.0863 - accuracy: 0.9743 - val_loss: 0.0811 - val_accuracy: 0.9735
# Epoch 4/10
# 300/300 [==============================] - 10s 33ms/step - loss: 0.0681 - accuracy: 0.9797 - val_loss: 0.0578 - val_accuracy: 0.9811
# Epoch 5/10
# 300/300 [==============================] - 11s 36ms/step - loss: 0.0573 - accuracy: 0.9824 - val_loss: 0.0519 - val_accuracy: 0.9820
# Epoch 6/10
# 300/300 [==============================] - 10s 34ms/step - loss: 0.0503 - accuracy: 0.9845 - val_loss: 0.0457 - val_accuracy: 0.9848
# Epoch 7/10
# 300/300 [==============================] - 10s 34ms/step - loss: 0.0467 - accuracy: 0.9856 - val_loss: 0.0408 - val_accuracy: 0.9869
# Epoch 8/10
# 300/300 [==============================] - 10s 33ms/step - loss: 0.0406 - accuracy: 0.9875 - val_loss: 0.0377 - val_accuracy: 0.9863
# Epoch 9/10
# 300/300 [==============================] - 10s 34ms/step - loss: 0.0372 - accuracy: 0.9886 - val_loss: 0.0421 - val_accuracy: 0.9860
# Epoch 10/10
# 300/300 [==============================] - 10s 33ms/step - loss: 0.0335 - accuracy: 0.9900 - val_loss: 0.0409 - val_accuracy: 0.9862

# %%
# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Accuracy: 0.9861999750137329
#  Error: 1.380002498626709

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by [Alex Aklson](https://www.linkedin.com/in/aklson/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0101ENSkillsNetwork20718188-2021-01-01). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description                                          |
# | ----------------- | ------- | ---------- | ----------------------------------------------------------- |
# | 2020-09-21        | 2.0     | Srishti    | Migrated Lab to Markdown and added to course repo in GitLab |
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>

# %% [markdown]
# This notebook is part of a course on **Coursera** called *Introduction to Deep Learning & Neural Networks with Keras*. If you accessed this notebook outside the course, you can take this course online by clicking [here](https://cocl.us/DL0101EN_Coursera_Week4\_LAB1).

# %% [markdown]
# <hr>
#
# Copyright © 2019 [IBM Developer Skills Network](https://cognitiveclass.ai/?utm_medium=dswb&utm_source=bducopyrightlink&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0101ENSkillsNetwork20718188-2021-01-01&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0101ENSkillsNetwork20718188-2021-01-01).
